-- %%
select *, '' as live_uid,'' as live_hid from UserInfo where uid = 'A04'
-- Out:
-- (1 列受影響)
--
-- uid | cname | password | birthday                    | live_uid | live_hid
-- ----+-------+----------+-----------------------------+----------+---------
-- A04 | 朱小妹   | NULL     | 2000-11-12 00:00:00.0000000 |          |
-- (1 個資料列)
--
-- 總執行時間: 00:00:00.029

-- %%
select * from Live
-- Out:
-- (4 個資料列受到影響)
--
-- uid | hid
-- ----+----
-- A01 | 1
-- A01 | 3
-- A02 | 1
-- A03 | 1
-- (4 個資料列)
--
-- 總執行時間: 00:00:00.051
